# %% [markdown]
# ### 1. Write a python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('List all the header tags :', *titles, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# ...

# %% [markdown]
# ### 2.Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
 


url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')
 
movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
 
ratings = [b.attrs.get('data-value')
           for b in soup.select('td.posterColumn span[name=ir]')]
 
votes = [b.attrs.get('data-value')
         for b in soup.select('td.ratingColumn strong')]
 
list = []


 

for index in range(0, 100):
     
  
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    list.append(data)

    

df=pd.DataFrame(columns=['movie_title', 'year','rating'], data=list)
df
# Out:
#                                movie_title  year             rating
# 0                 The Shawshank Redemption  1994  9.219877342725631
# 1                            The Godfather  1972  9.147522333342243
# 2                   The Godfather: Part II  1974  8.980045216119926
# 3                          The Dark Knight  2008  8.970310008760025
# 4                             12 Angry Men  1957  8.935393823816817
# ..                                     ...   ...                ...
# 95                                  Jagten  2012  8.261400250344483
# 96                            Idi i smotri  1985  8.258563448259371
# 97                     Singin' in the Rain  1952  8.257996487677797
# 98                      North by Northwest  1959  8.257948879604385
# 99   Eternal Sunshine of the Spotless Mind  2004  8.256699757529672
#
# [100 rows x 3 columns]

# %% [markdown]
# ### 3.Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
 


url = 'https://www.imdb.com/india/top-rated-indian-movies'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')
 
movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
 
ratings = [b.attrs.get('data-value')
           for b in soup.select('td.posterColumn span[name=ir]')]
 
votes = [b.attrs.get('data-value')
         for b in soup.select('td.ratingColumn strong')]
 
list = []


 

for index in range(0, 100):
     
  
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    list.append(data)

    

df=pd.DataFrame(columns=['movie_title', 'year','rating'], data=list)
df
# Out:
#                  movie_title  year             rating
# 0            Pather Panchali  1955   8.49574714373411
# 1                    Nayakan  1987   8.48535636796388
# 2          Pariyerum Perumal  2018  8.478279680679526
# 3                 Anbe Sivam  2003  8.475265240787863
# 4                    Golmaal  1979  8.463586073123725
# ..                       ...   ...                ...
# 95           Andaz Apna Apna  1994  8.067085418117005
# 96                 Virumandi  2004  8.065833680796263
# 97  Uri: The Surgical Strike  2018  8.065266458562444
# 98                        PK  2014    8.0629403072961
# 99                     Lucia  2013   8.05510775965791
#
# [100 rows x 3 columns]

# %% [markdown]
# ### 4.Write a python program to scrap book name, author name, genre and book review of any 5 books from 'www.bookpage.com'

# %%
from bs4 import BeautifulSoup
import requests
import re
import dateutil

page=requests.get("https://bookpage.com/reviews")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang=\'en\' xmlns:fb=\'http://www.facebook.com/2008/fbml\' xmlns:og=\'http://opengraphprotocol.org/schema/\'>\n<head>\n<title>Book Reviews | BookPage</title>\n<meta name="description" content="Book recommendations of the best new books by genre and more.">\n<meta name="keywords" content="book reviews, books and literature, writing and writers">\n<link rel="canonical" href="https://bookpage.com/reviews">\n<meta property="og:site_name" content="BookPage.com">\n<meta property="og:title" content="Book Reviews">\n<meta property="og:description" content="Book recommendations of the best new books by genre and more.">\n<meta property="og:type" content="website">\n<meta property="og:url" content="https://bookpage.com/reviews">\n<meta property="og:image" content="//www.bookpage.com/default_image.jpg">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:site" content="@bookpage">\n<meta name="twitter:creator" content="@bookpage">\n<meta name="robots" con
# ...

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title>Book Reviews | BookPage</title>
# <meta content="Book recommendations of the best new books by genre and more." name="description"/>
# <meta content="book reviews, books and literature, writing and writers" name="keywords"/>
# <link href="https://bookpage.com/reviews" rel="canonical"/>
# <meta content="BookPage.com" property="og:site_name"/>
# <meta content="Book Reviews" property="og:title"/>
# <meta content="Book recommendations of the best new books by genre and more." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://bookpage.com/reviews" property="og:url"/>
# <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@bookpage" name="twitter:site"/>
# <meta content="@bookpage" name="twitter:creator"/>
# ...

# %%
Book= []

detail = soup.find_all('h4', class_="italic")

for i in detail:

    Book.append(i.a.text.strip())

# %%
Book
# Out:
# ['Filthy Animals',
#  'The Woman They Could Not Silence',
#  'Under a Dancing Star',
#  'Yoke',
#  'Leaving Isn’t the Hardest Thing',
#  'The Rose Code',
#  'The Damage',
#  '★ Blackout',
#  '★ The Sweetness of Water',
#  'The Killing Hills']

# %%
b_name=[]
for i in range(0,len(Book),1):

    b_name.append(Book[i])

# %%
b_name
# Out:
# ['Filthy Animals',
#  'The Woman They Could Not Silence',
#  'Under a Dancing Star',
#  'Yoke',
#  'Leaving Isn’t the Hardest Thing',
#  'The Rose Code',
#  'The Damage',
#  '★ Blackout',
#  '★ The Sweetness of Water',
#  'The Killing Hills']

# %%
len(b_name)
# Out:
# 10

# %%
a_name= []

detail = soup.find_all('p', class_="sans bold")

for i in detail:

    a_name.append(i.text.replace('\n',''))

# %%
a_name
# Out:
# ['Brandon Taylor',
#  'Kate Moore',
#  'Laura Wood',
#  'Jessamyn Stanley',
#  'Lauren Hough, Cate Blanchett',
#  'Kate Quinn, Saskia Maarleveld',
#  'Caitlin Wahrer',
#  'Dhonielle Clayton, Tiffany D. Jackson, Nic Stone, Angie Thomas, Ashley Woodfolk, Nicola Yoon',
#  'Nathan Harris',
#  'Chris Offutt']

# %%
A_name=[]
for i in range(0,len(a_name),1):

    A_name.append(a_name[i])

# %%
A_name
# Out:
# ['Brandon Taylor',
#  'Kate Moore',
#  'Laura Wood',
#  'Jessamyn Stanley',
#  'Lauren Hough, Cate Blanchett',
#  'Kate Quinn, Saskia Maarleveld',
#  'Caitlin Wahrer',
#  'Dhonielle Clayton, Tiffany D. Jackson, Nic Stone, Angie Thomas, Ashley Woodfolk, Nicola Yoon',
#  'Nathan Harris',
#  'Chris Offutt']

# %%
len(A_name)
# Out:
# 10

# %%
gen= []

detail = soup.find_all('p', class_="genre-links hidden-phone")

for i in detail:

    gen.append(i.text.replace('\n',''))

# %%
gen
# Out:
# ['Fiction / Short Stories',
#  "Nonfiction / History / Women's History",
#  'YA / YA Fiction',
#  'Nonfiction / Essays / Body, Mind & Spirit',
#  'Audio / Nonfiction / Essays',
#  'Audio / Fiction / Historical Fiction',
#  'Mystery & Suspense / Suspense',
#  'YA / YA Fiction',
#  'Fiction / Historical Fiction',
#  'Fiction / Crime Fiction']

# %%
genre=[]
for i in range(0,len(gen),1):

    genre.append(gen[i].replace('/',','))

# %%
genre
# Out:
# ['Fiction , Short Stories',
#  "Nonfiction , History , Women's History",
#  'YA , YA Fiction',
#  'Nonfiction , Essays , Body, Mind & Spirit',
#  'Audio , Nonfiction , Essays',
#  'Audio , Fiction , Historical Fiction',
#  'Mystery & Suspense , Suspense',
#  'YA , YA Fiction',
#  'Fiction , Historical Fiction',
#  'Fiction , Crime Fiction']

# %%
review= []

re = soup.find_all('p', class_="excerpt")

for i in re:

    review.append(i.text.replace("\n"," "))

# %%
review
# Out:
# [' In Brandon Taylor’s short story collection, sexual tension acts like an undertow, lurking to pull its victims down below. ',
#  ' In the 19th century, a brave, brilliant and completely healthy woman named Elizabeth Packard was involuntarily committed to an Illinois asylum by her husband. ',
#  ' ',
#  ' The 13 autobiographical essays in Yoke are brash, outspoken, funny, insightful, honest and occasionally spiced with dashes of self-deprecating melodrama. ',
#  ' Author Lauren Hough and actor-producer Cate Blanchett create a heartbreaking and intimate experience for listeners. ',
#  ' The Rose Code is a terrific story, brilliantly performed by Saskia Maarleveld. Or as Osla would say, it’s a real corker! ',
#  ' ',
#  ' ',
#  ' Nathan Harris’ Civil War-set debut novel celebrates all manner of relationships that combat hate. ',
#  ' A rural noir with attitude to spare, The Killing Hills moves as briskly as a well-constructed miniseries. ']

# %%
Review=[]
for i in range(0,len(review),1):

    Review.append(review[i])

# %%
Review
# Out:
# [' In Brandon Taylor’s short story collection, sexual tension acts like an undertow, lurking to pull its victims down below. ',
#  ' In the 19th century, a brave, brilliant and completely healthy woman named Elizabeth Packard was involuntarily committed to an Illinois asylum by her husband. ',
#  ' ',
#  ' The 13 autobiographical essays in Yoke are brash, outspoken, funny, insightful, honest and occasionally spiced with dashes of self-deprecating melodrama. ',
#  ' Author Lauren Hough and actor-producer Cate Blanchett create a heartbreaking and intimate experience for listeners. ',
#  ' The Rose Code is a terrific story, brilliantly performed by Saskia Maarleveld. Or as Osla would say, it’s a real corker! ',
#  ' ',
#  ' ',
#  ' Nathan Harris’ Civil War-set debut novel celebrates all manner of relationships that combat hate. ',
#  ' A rural noir with attitude to spare, The Killing Hills moves as briskly as a well-constructed miniseries. ']

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Book_name']=b_name
jobs['Author_Name']=A_name
jobs['Genre']=genre
jobs['Review']=Review

# %%
jobs
# Out:
#                           Book_name  \
# 0                    Filthy Animals
# 1  The Woman They Could Not Silence
# 2              Under a Dancing Star
# 3                              Yoke
# 4   Leaving Isn’t the Hardest Thing
# 5                     The Rose Code
# 6                        The Damage
# 7                        ★ Blackout
# 8          ★ The Sweetness of Water
# 9                 The Killing Hills
#
#                                          Author_Name  \
# 0                                     Brandon Taylor
# 1                                         Kate Moore
# 2                                         Laura Wood
# 3                                   Jessamyn Stanley
# 4                       Lauren Hough, Cate Blanchett
# 5                      Kate Quinn, Saskia Maarleveld
# 6                                     Caitlin Wahrer
# 7  Dhonielle Clayton, Tiffany D. Jackson, Nic Sto...
# 8                                      Nathan Harris
# ...

# %%
jobs.index+=1

# %%
jobs
# Out:
#                            Book_name  \
# 1                     Filthy Animals
# 2   The Woman They Could Not Silence
# 3               Under a Dancing Star
# 4                               Yoke
# 5    Leaving Isn’t the Hardest Thing
# 6                      The Rose Code
# 7                         The Damage
# 8                         ★ Blackout
# 9           ★ The Sweetness of Water
# 10                 The Killing Hills
#
#                                           Author_Name  \
# 1                                      Brandon Taylor
# 2                                          Kate Moore
# 3                                          Laura Wood
# 4                                    Jessamyn Stanley
# 5                        Lauren Hough, Cate Blanchett
# 6                       Kate Quinn, Saskia Maarleveld
# 7                                      Caitlin Wahrer
# 8   Dhonielle Clayton, Tiffany D. Jackson, Nic Sto...
# 9                                       Nathan Harris
# ...

# %% [markdown]
# ### 5.Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:

# %% [markdown]
# #### i)Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
import dateutil
import pandas as pd

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
page
# Out:
# <Response [200]>

# %%
assert page.status_code==200

# %%
src=page.content
document=BeautifulSoup(src,'lxml')

# %%
table=document.find('table')
table
# Out:
# <table class="table">
# <thead>
# <tr class="table-head">
# <th class="table-head__cell u-text-right">Pos</th>
# <th class="table-head__cell rankings-table__team">
# <span class="u-hide-mobile">Team</span>
# <span class="u-show-mobile">T</span>
# </th>
# <th class="table-head__cell u-center-text">
# <span class="u-hide-mobile">Matches</span>
# <span class="u-show-mobile">M</span>
# </th>
# <th class="table-head__cell u-center-text">
# <span class="u-hide-mobile">Points</span>
# <span class="u-show-mobile">P</span>
# </th>
# <th class="table-head__cell u-text-right rating">
# <span class="u-hide-mobile">Rating</span>
# <span class="u-show-mobile">R</span>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr class="rankings-block__banner">
# <td class="rankings-block__banner--pos">1</td>
# <td class="rankings-block__banner--team-name">
# <span class="flag-30 rankings-block__banner--flag NZ"></span>
# <span class="u-hide-phablet">New Zealand</span>
# <span class="u-show-phablet">NZ</span>
# ...

# %%
assert table.find("th").get_text()=="Pos"

# %%
rows=table.find_all("tr")
rows
# Out:
# [<tr class="table-head">
#  <th class="table-head__cell u-text-right">Pos</th>
#  <th class="table-head__cell rankings-table__team">
#  <span class="u-hide-mobile">Team</span>
#  <span class="u-show-mobile">T</span>
#  </th>
#  <th class="table-head__cell u-center-text">
#  <span class="u-hide-mobile">Matches</span>
#  <span class="u-show-mobile">M</span>
#  </th>
#  <th class="table-head__cell u-center-text">
#  <span class="u-hide-mobile">Points</span>
#  <span class="u-show-mobile">P</span>
#  </th>
#  <th class="table-head__cell u-text-right rating">
#  <span class="u-hide-mobile">Rating</span>
#  <span class="u-show-mobile">R</span>
#  </th>
#  </tr>,
#  <tr class="rankings-block__banner">
#  <td class="rankings-block__banner--pos">1</td>
#  <td class="rankings-block__banner--team-name">
#  <span class="flag-30 rankings-block__banner--flag NZ"></span>
#  <span class="u-hide-phablet">New Zealand</span>
#  <span class="u-show-phablet">NZ</span>
#  </td>
# ...

# %%
for row in rows[1:11]:
    cells=row.find_all(["td","th"])

    cells_text=[cell.get_text(strip=True)for cell in cells]
    (POS,TEAMS,MATCHES,POINTS,RATING)=cells_text
    

  
    print(f"{POS},{TEAMS},{MATCHES},{POINTS},{RATING}")
# Out:
# 1,New ZealandNZ,17,2,054,121
# 2,AustraliaAUS,25,2,945,118
# 3,IndiaIND,29,3,344,115
# 4,EnglandENG,27,3,100,115
# 5,South AfricaSA,20,2,137,107
# 6,PakistanPAK,24,2,323,97
# 7,BangladeshBAN,27,2,438,90
# 8,West IndiesWI,27,2,222,82
# 9,Sri LankaSL,24,1,876,78
# 10,AfghanistanAFG,17,1,054,62

# %% [markdown]
# #### ii)Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
import dateutil

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting")
page
# Out:
# <Response [200]>

# %%
assert page.status_code==200

# %%
src=page.content
document=BeautifulSoup(src,'lxml')

# %%
table=document.find('table')
table
# Out:
# <table class="table rankings-table">
# <thead>
# <tr class="table-head">
# <th class="table-head__cell u-text-right">Pos</th>
# <th class="table-head__cell">Player</th>
# <th class="table-head__cell">Team</th>
# <th class="table-head__cell table-head__cell--rating">Rating</th>
# <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
# </tr>
# </thead>
# <tr class="rankings-block__banner">
# <td class="rankings-block__position">1</td>
# <td class="rankings-block__top-player-container">
# <div class="u-flex-center u-text-left">
# <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
# <a href="/rankings/mens/player-rankings/2759">
# <img alt="Player Image" class="rankings-block__player-image image-missing" data-error="true" data-player="2759" data-size="130x150" data-widget="player-image" src="//resources.pulse.icc-cricket.com/players/130x150/Photo-Missing.png"/>
# </a>
# </div>
# <div>
# ...

# %%
assert table.find("th").get_text()=="Pos"

# %%
rows=table.find_all("tr")
rows
# Out:
# [<tr class="table-head">
#  <th class="table-head__cell u-text-right">Pos</th>
#  <th class="table-head__cell">Player</th>
#  <th class="table-head__cell">Team</th>
#  <th class="table-head__cell table-head__cell--rating">Rating</th>
#  <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
#  </tr>,
#  <tr class="rankings-block__banner">
#  <td class="rankings-block__position">1</td>
#  <td class="rankings-block__top-player-container">
#  <div class="u-flex-center u-text-left">
#  <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
#  <a href="/rankings/mens/player-rankings/2759">
#  <img alt="Player Image" class="rankings-block__player-image image-missing" data-error="true" data-player="2759" data-size="130x150" data-widget="player-image" src="//resources.pulse.icc-cricket.com/players/130x150/Photo-Missing.png"/>
#  </a>
#  </div>
#  <div>
# ...

# %%
for row in rows[1:11]:
    cells=row.find_all(["td","th"])

    cells_text=[cell.get_text(strip=True)for cell in cells]
    (POS,PLAYER,TEAM,RATING,CAREER_BEST_RATING)=cells_text
    

    
    print(f"{POS},{PLAYER},{TEAM},{RATING},{CAREER_BEST_RATING}")
# Out:
# 1,Babar Azam,PAK,865,865 v South Africa, 07/04/2021
# 2,Virat Kohli,IND,857,911 v England, 12/07/2018
# 3,Rohit Sharma,IND,825,885 v Sri Lanka, 06/07/2019
# 4,Ross Taylor,NZ,801,841 v Bangladesh, 05/06/2019
# 5,Aaron Finch,AUS,791,798 v England, 25/06/2019
# 6,Jonny Bairstow,ENG,785,796 v India, 26/03/2021
# 7,Fakhar Zaman,PAK,778,778 v South Africa, 07/04/2021
# ,Francois du Plessis,SA,778,820 v Australia, 06/07/2019
# 9,David Warner,AUS,773,880 v Pakistan, 26/01/2017
# ,Shai Hope,WI,773,808 v Bangladesh, 17/05/2019

# %% [markdown]
# #### iii)Top 10 ODI bowlers along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
import dateutil

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")
page
# Out:
# <Response [200]>

# %%
assert page.status_code==200

# %%
src=page.content
document=BeautifulSoup(src,'lxml')

# %%
table=document.find('table')
table
# Out:
# <table class="table rankings-table">
# <thead>
# <tr class="table-head">
# <th class="table-head__cell u-text-right">Pos</th>
# <th class="table-head__cell">Player</th>
# <th class="table-head__cell">Team</th>
# <th class="table-head__cell table-head__cell--rating">Rating</th>
# <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
# </tr>
# </thead>
# <tr class="rankings-block__banner">
# <td class="rankings-block__position">1</td>
# <td class="rankings-block__top-player-container">
# <div class="u-flex-center u-text-left">
# <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
# <a href="/rankings/mens/player-rankings/969">
# <img alt="Player Image" class="rankings-block__player-image image-missing" data-error="true" data-player="969" data-size="130x150" data-widget="player-image" src="//resources.pulse.icc-cricket.com/players/130x150/Photo-Missing.png"/>
# </a>
# </div>
# <div>
# ...

# %%
assert table.find("th").get_text()=="Pos"

# %%
rows=table.find_all("tr")
rows
# Out:
# [<tr class="table-head">
#  <th class="table-head__cell u-text-right">Pos</th>
#  <th class="table-head__cell">Player</th>
#  <th class="table-head__cell">Team</th>
#  <th class="table-head__cell table-head__cell--rating">Rating</th>
#  <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
#  </tr>,
#  <tr class="rankings-block__banner">
#  <td class="rankings-block__position">1</td>
#  <td class="rankings-block__top-player-container">
#  <div class="u-flex-center u-text-left">
#  <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
#  <a href="/rankings/mens/player-rankings/969">
#  <img alt="Player Image" class="rankings-block__player-image image-missing" data-error="true" data-player="969" data-size="130x150" data-widget="player-image" src="//resources.pulse.icc-cricket.com/players/130x150/Photo-Missing.png"/>
#  </a>
#  </div>
#  <div>
# ...

# %%
for row in rows[1:11]:
    cells=row.find_all(["td","th"])

    cells_text=[cell.get_text(strip=True)for cell in cells]
    (POS,PLAYER,TEAM,RATING,CAREER_BEST_RATING)=cells_text
    

    
    print(f"{POS},{PLAYER},{TEAM},{RATING},{CAREER_BEST_RATING}")
# Out:
# 1,Trent Boult,NZ,737,770 v West Indies, 22/06/2019
# 2,Mehedi Hasan,BAN,713,725 v Sri Lanka, 25/05/2021
# 3,Mujeeb Ur Rahman,AFG,708,712 v Ireland, 24/01/2021
# 4,Matt Henry,NZ,691,691 v Bangladesh, 26/03/2021
# 5,Jasprit Bumrah,IND,690,841 v West Indies, 01/11/2018
# 6,Kagiso Rabada,SA,666,724 v England, 29/05/2017
# 7,Chris Woakes,ENG,665,676 v New Zealand, 14/07/2019
# 8,Josh Hazlewood,AUS,660,733 v England, 26/01/2018
# 9,Pat Cummins,AUS,646,729 v Pakistan, 12/06/2019
# 10,Mustafizur Rahman,BAN,645,695 v West Indies, 14/12/2018

# %% [markdown]
# ### 6.Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:

# %% [markdown]
# #### 1.Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
import dateutil
import pandas as pd

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
page
assert page.status_code==200
src=page.content
document=BeautifulSoup(src,'lxml')
table=document.find('table')
table
# Out:
# <table class="table">
# <thead>
# <tr class="table-head">
# <th class="table-head__cell u-text-right">Pos</th>
# <th class="table-head__cell rankings-table__team">
# <span class="u-hide-mobile">Team</span>
# <span class="u-show-mobile">T</span>
# </th>
# <th class="table-head__cell u-center-text">
# <span class="u-hide-mobile">Matches</span>
# <span class="u-show-mobile">M</span>
# </th>
# <th class="table-head__cell u-center-text">
# <span class="u-hide-mobile">Points</span>
# <span class="u-show-mobile">P</span>
# </th>
# <th class="table-head__cell u-text-right rating">
# <span class="u-hide-mobile">Rating</span>
# <span class="u-show-mobile">R</span>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr class="rankings-block__banner">
# <td class="rankings-block__banner--pos">1</td>
# <td class="rankings-block__banner--team-name">
# <span class="flag-30 rankings-block__banner--flag AUS"></span>
# <span class="u-hide-phablet">Australia</span>
# <span class="u-show-phablet">AUS</span>
# ...

# %%
assert table.find("th").get_text()=="Pos"

# %%
rows=table.find_all("tr")
rows
# Out:
# [<tr class="table-head">
#  <th class="table-head__cell u-text-right">Pos</th>
#  <th class="table-head__cell rankings-table__team">
#  <span class="u-hide-mobile">Team</span>
#  <span class="u-show-mobile">T</span>
#  </th>
#  <th class="table-head__cell u-center-text">
#  <span class="u-hide-mobile">Matches</span>
#  <span class="u-show-mobile">M</span>
#  </th>
#  <th class="table-head__cell u-center-text">
#  <span class="u-hide-mobile">Points</span>
#  <span class="u-show-mobile">P</span>
#  </th>
#  <th class="table-head__cell u-text-right rating">
#  <span class="u-hide-mobile">Rating</span>
#  <span class="u-show-mobile">R</span>
#  </th>
#  </tr>,
#  <tr class="rankings-block__banner">
#  <td class="rankings-block__banner--pos">1</td>
#  <td class="rankings-block__banner--team-name">
#  <span class="flag-30 rankings-block__banner--flag AUS"></span>
#  <span class="u-hide-phablet">Australia</span>
#  <span class="u-show-phablet">AUS</span>
#  </td>
# ...

# %%
for row in rows[1:11]:
    cells=row.find_all(["td","th"])

    cells_text=[cell.get_text(strip=True)for cell in cells]
    (POS,TEAMS,MATCHES,POINTS,RATING)=cells_text
    

  
    print(f"{POS},{TEAMS},{MATCHES},{POINTS},{RATING}")
# Out:
# 1,AustraliaAUS,18,2,955,164
# 2,South AfricaSA,24,2,828,118
# 3,EnglandENG,17,1,993,117
# 4,IndiaIND,20,2,226,111
# 5,New ZealandNZ,21,1,947,93
# 6,West IndiesWI,12,1,025,85
# 7,PakistanPAK,15,1,101,73
# 8,BangladeshBAN,5,306,61
# 9,Sri LankaSL,11,519,47
# 10,IrelandIRE,2,25,13

# %% [markdown]
# #### ii)Top 10 women’s ODI players along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
import dateutil
import pandas as pd

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting")
page
assert page.status_code==200
src=page.content
document=BeautifulSoup(src,'lxml')
table=document.find('table')
table
# Out:
# <table class="table rankings-table">
# <thead>
# <tr class="table-head">
# <th class="table-head__cell u-text-right">Pos</th>
# <th class="table-head__cell">Player</th>
# <th class="table-head__cell">Team</th>
# <th class="table-head__cell table-head__cell--rating">Rating</th>
# <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
# </tr>
# </thead>
# <tr class="rankings-block__banner">
# <td class="rankings-block__position">1</td>
# <td class="rankings-block__top-player-container">
# <div class="u-flex-center u-text-left">
# <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
# <a href="/rankings/womens/player-rankings/545">
# <img alt="Player Image" class="rankings-block__player-image image-missing" data-error="true" data-player="545" data-size="130x150" data-widget="player-image" src="//resources.pulse.icc-cricket.com/players/130x150/Photo-Missing.png"/>
# </a>
# </div>
# <div>
# ...

# %%
assert table.find("th").get_text()=="Pos"

# %%
rows=table.find_all("tr")
rows
# Out:
# [<tr class="table-head">
#  <th class="table-head__cell u-text-right">Pos</th>
#  <th class="table-head__cell">Player</th>
#  <th class="table-head__cell">Team</th>
#  <th class="table-head__cell table-head__cell--rating">Rating</th>
#  <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
#  </tr>,
#  <tr class="rankings-block__banner">
#  <td class="rankings-block__position">1</td>
#  <td class="rankings-block__top-player-container">
#  <div class="u-flex-center u-text-left">
#  <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
#  <a href="/rankings/womens/player-rankings/545">
#  <img alt="Player Image" class="rankings-block__player-image image-missing" data-error="true" data-player="545" data-size="130x150" data-widget="player-image" src="//resources.pulse.icc-cricket.com/players/130x150/Photo-Missing.png"/>
#  </a>
#  </div>
#  <div>
# ...

# %%
for row in rows[1:11]:
    cells=row.find_all(["td","th"])

    cells_text=[cell.get_text(strip=True)for cell in cells]
    (POS,PLAYER,TEAM,RATING,CAREER_BEST_RATING)=cells_text
    

    
    print(f"{POS},{PLAYER},{TEAM},{RATING},{CAREER_BEST_RATING}")
# Out:
# 1,Tammy Beaumont,ENG,765,765 v New Zealand, 28/02/2021
# 2,Lizelle Lee,SA,758,773 v India, 14/03/2021
# 3,Alyssa Healy,AUS,756,756 v New Zealand, 10/04/2021
# 4,Stafanie Taylor,WI,746,765 v India, 02/03/2012
# 5,Meg Lanning,AUS,723,834 v New Zealand, 24/02/2016
# 6,Amy Satterthwaite,NZ,715,756 v Australia, 02/03/2017
# 7,Smriti Mandhana,IND,710,797 v England, 28/02/2019
# 8,Mithali Raj,IND,709,839 v Australia, 24/12/2004
# 9This player has moved up in the rankings since the previous rankings update,Natalie Sciver,ENG,685,712 v India, 25/02/2019
# 10This player has moved up in the rankings since the previous rankings update,Laura Wolvaardt,SA,683,725 v India, 07/03/2021

# %% [markdown]
# #### iii)Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
import dateutil
import pandas as pd

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")
page
# Out:
# <Response [200]>

# %%
assert page.status_code==200

# %%
html_content = page.text
soup_object = BeautifulSoup(html_content, "lxml")

# %%
data_dict = dict()

# %%
table=document.find('table')
table
# Out:
# <table class="table rankings-table">
# <thead>
# <tr class="table-head">
# <th class="table-head__cell u-text-right">Pos</th>
# <th class="table-head__cell">Player</th>
# <th class="table-head__cell">Team</th>
# <th class="table-head__cell table-head__cell--rating">Rating</th>
# <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
# </tr>
# </thead>
# <tr class="rankings-block__banner">
# <td class="rankings-block__position">1</td>
# <td class="rankings-block__top-player-container">
# <div class="u-flex-center u-text-left">
# <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
# <a href="/rankings/womens/player-rankings/424">
# <img alt="Player Image" class="rankings-block__player-image image-missing" data-error="true" data-player="424" data-size="130x150" data-widget="player-image" src="//resources.pulse.icc-cricket.com/players/130x150/Photo-Missing.png"/>
# </a>
# </div>
# <div>
# ...

# %%
assert table.find("th").get_text()=="Pos"

# %%
rows=table.find_all("tr")
rows
# Out:
# [<tr class="table-head">
#  <th class="table-head__cell u-text-right">Pos</th>
#  <th class="table-head__cell">Player</th>
#  <th class="table-head__cell">Team</th>
#  <th class="table-head__cell table-head__cell--rating">Rating</th>
#  <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
#  </tr>,
#  <tr class="rankings-block__banner">
#  <td class="rankings-block__position">1</td>
#  <td class="rankings-block__top-player-container">
#  <div class="u-flex-center u-text-left">
#  <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
#  <a href="/rankings/womens/player-rankings/424">
#  <img alt="Player Image" class="rankings-block__player-image image-missing" data-error="true" data-player="424" data-size="130x150" data-widget="player-image" src="//resources.pulse.icc-cricket.com/players/130x150/Photo-Missing.png"/>
#  </a>
#  </div>
#  <div>
# ...

# %%
for row in rows[1:11]:
    cells=row.find_all(["td","th"])

    cells_text=[cell.get_text(strip=True)for cell in cells]
    (POS,PLAYER,TEAM,RATING,CAREER_BEST_RATING)=cells_text
    
    
  

    
    print(f"{POS},{PLAYER},{TEAM},{RATING},{CAREER_BEST_RATING}")
# Out:
# 1,Marizanne Kapp,SA,418,418 v India, 17/03/2021
# ,Ellyse Perry,AUS,418,548 v West Indies, 11/09/2019
# 3,Stafanie Taylor,WI,410,559 v New Zealand, 10/10/2013
# 4,Natalie Sciver,ENG,349,349 v New Zealand, 28/02/2021
# 5,Deepti Sharma,IND,343,397 v South Africa, 09/10/2019
# 6,Jess Jonassen,AUS,307,308 v West Indies, 11/09/2019
# 7,Ashleigh Gardner,AUS,252,256 v New Zealand, 04/04/2021
# 8,Dane van Niekerk,SA,243,421 v Sri Lanka, 11/02/2019
# 9This player has moved down in the rankings since the previous rankings update,Sophie Devine,NZ,242,305 v Australia, 05/10/2020
# 10This player has moved down in the rankings since the previous rankings update,Amelia Kerr,NZ,236,247 v Australia, 07/04/2021

# %% [markdown]
# ### 7.Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The scraped data should include Product Name, Price, Image URL and Average Rating.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
from selenium import webdriver

# %%
from msedge.selenium_tools import Edge,EdgeOptions

# %%
driver=webdriver.Firefox()
driver=webdriver.Chrome()

# %%
options=EdgeOptions()
options.use_chromium=True
driver=Edge(options=options)

# %%
url='https://www.amazon.in'
driver.get(url)

# %%
def get_url(search_term):
    template="https://www.amazon.in/s?k=mobiles&ref=nb_sb_noss_2"
    search_term=search_term.replace(' ','+')
    return template.format(search_term)

# %%
url=get_url('mobiles')
print(url)
# Out:
# https://www.amazon.in/s?k=mobiles&ref=nb_sb_noss_2

# %%
driver.get(url)

# %% [markdown]
# ### Extract the collection

# %%
soup=BeautifulSoup(driver.page_source,'html.parser')

# %%
results=soup.find_all('div',{'data-component-type':'s-search-result'})

# %%
len(results)
# Out:
# 22

# %%
item=results[0]

# %%
atag=item.h2.a

# %%
description=atag.text.strip()

# %%
atag.get('href')
# Out:
# '/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A03203451PJS51LCV5CR0&url=%2FFantastic-Purple-Storage-Charge-Display%2Fdp%2FB08VB34KJ1%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3Dmobiles%26qid%3D1624366311%26sr%3D8-1-spons%26psc%3D1&qualifier=1624366311&id=235786291527348&widgetName=sp_atf'

# %%
url='https://www.amazon.in' + atag.get('href')

# %%
price_parent=item.find('span','a-price')

# %%
price=price_parent.find('span','a-offscreen').text

# %%
item.i.text
# Out:
# '4.2 out of 5 stars'

# %%
rating=item.i.text

# %%
review_count=item.find('span',{'class':'a-size-base'}).text

# %% [markdown]
# ### Generalize the pattern

# %%
def extract_record(item):
    """extract and return data from a single record"""
    #decription and url
    atag=item.h2.a
    description=atag.text.strip()
    url='https://www.amazon.in' + atag.get('href')
    
    #price
    price_parent=item.find('span','a-price')
    price=price_parent.find('span','a-offscreen').text
    
    #rank and  rating
    
    rating=item.i.text
    review_count=item.find('span',{'class':'a-size-base'}).text
    
    result=(description,price,rating,review_count,url)
    
    return result

# %%
records=[]
results=soup.find_all('div',{'data-component-type':'s-search-result'})

for item in results:
    records.append(extract_record(item))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ae7a94154fc3> in <module>
#       3
#       4 for item in results:
# ----> 5     records.append(extract_record(item))
#
# <ipython-input-25-e17fa1bc5f9d> in extract_record(item)
#       8     #price
#       9     price_parent=item.find('span','a-price')
# ---> 10     price=price_parent.find('span','a-offscreen').text
#      11
#      12     #rank and  rating
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %% [markdown]
# ### Error handling

# %%
def extract_record(item):
    """extract and return data from a single record"""
    #decription and url
    atag=item.h2.a
    description=atag.text.strip()
    url='https://www.amazon.in' + atag.get('href')
    
    try:
        #price
        price_parent=item.find('span','a-price')
        price=price_parent.find('span','a-offscreen').text
    except AttributeError:
        return

    try:
        #rank and  rating

        rating=item.i.text
        review_count=item.find('span',{'class':'a-size-base'}).text
    
    except AttributeError:
        rating=''
        review_count=''
    
    result=(description,price,rating,review_count,url)
    
    return result

# %%
records=[]
results=soup.find_all('div',{'data-component-type':'s-search-result'})

for item in results:
    record=extract_record(item)
    if record:
        
        records.append(record)

# %%
records[0]
# Out:
# ('OPPO A74 5G (Fantastic Purple, 6GB RAM, 128GB Storage)| 5000 mAh | 18W Fast Charge | 90Hz Super Amoled Display',
#  '₹17,990',
#  '4.2 out of 5 stars',
#  '1,605',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A03203451PJS51LCV5CR0&url=%2FFantastic-Purple-Storage-Charge-Display%2Fdp%2FB08VB34KJ1%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3Dmobiles%26qid%3D1624366311%26sr%3D8-1-spons%26psc%3D1&qualifier=1624366311&id=235786291527348&widgetName=sp_atf')

# %%
for row in records:
    print(row[1],)
# Out:
# ₹17,990
# ₹11,490
# ₹8,799
# ₹6,799
# ₹8,999
# ₹8,999
# ₹6,199
# ₹10,999
# ₹10,999
# ₹5,198
# ₹13,600
# ₹6,799
# ₹8,799
# ₹16,999
# ₹6,799
# ₹8,999
# ₹12,999
# ₹8,799
# ₹5,298
# ₹14,490
# ₹6,388

# %% [markdown]
# ### Getting the next page

# %%
def get_url(search_term):
    template="https://www.amazon.in/s?k=mobiles&ref=nb_sb_noss_2"
    search_term=search_term.replace(' ','+')
    
    #add term query to url
    url=template.format(search_term)
    
    #add page query placeholder
    url+='&page{}'
    
    return url

# %% [markdown]
# ### Putting all together

# %%
import csv
from bs4 import BeautifulSoup
from msedge.selenium_tools import Edge,EdgeOptions

def get_url(search_term):
    template="https://www.amazon.in/s?k=Mobile+phones+under+20000&ref=nb_sb_noss_2"
    search_term=search_term.replace(' ','+')
    
    #add term query to url
    url=template.format(search_term)
    
    #add page query placeholder
    url+='&page{}'
    
    return url

def extract_record(item):
    """extract and return data from a single record"""
    #decription and url
    atag=item.h2.a
    description=atag.text.strip()
    url='https://www.amazon.in' + atag.get('href')
    
    try:
        #price
        price_parent=item.find('span','a-price')
        price=price_parent.find('span','a-offscreen').text
    except AttributeError:
        return

    try:
        #rank and  rating

        rating=item.i.text
        review_count=item.find('span',{'class':'a-size-base'}).text
    
    except AttributeError:
        rating=''
        review_count=''
    
    result=(description,price,rating,review_count,url)
    
    return result

def main(search_term):
    """Run main program routine"""
    # startup the webdriver
    options=EdgeOptions()
    options.use_chromium=True
    driver=Edge(options=options)
    
    record=[]
    url=get_url(search_term)
    
    for page in range(1,10):
        driver.get(url.format(page))
        soup=BeautifulSoup(driver.page_source,'html.parser')
        results=soup.find_all('div',{'data-component-type':'s-search-result'})
        
        for item in results:
            record=extract_record(item)
            if record:
                records.append(record)
        
    driver.close()
    df = pd.DataFrame(record, columns=['Discription', 'Price','Rating','Review_count','Url'])

# %%
main('mobiles')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\laxmi\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1661                 blocks = [
# -> 1662                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1663                 ]
#
# C:\laxmi\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2721
# -> 2722     return klass(values, ndim=ndim, placement=placement)
#    2723
#
# C:\laxmi\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2377
# -> 2378         super().__init__(values, ndim=ndim, placement=placement)
#    2379
#
# C:\laxmi\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
# ...

# %%
df
# Out:
#                                            Description    Price  \
# 0    OPPO A74 5G (Fantastic Purple, 6GB RAM, 128GB ...  ₹17,990
# 1    OPPO A15s (Rainbow Silver, 4GB RAM, 64GB Stora...  ₹11,490
# 2    Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 500...   ₹8,799
# 3    Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...   ₹6,799
# 4    TECNO Spark 7T(Jewel Blue, 4GB RAM, 64GB Stora...   ₹8,999
# ..                                                 ...      ...
# 862  Panasonic Eluga i7 (2GB RAM, 16GB Storage, Fin...   ₹5,298
# 863  OPPO A31 (Mystery Black, 4GB RAM, 64GB Storage...  ₹10,490
# 864  Redmi Note 10 (Shadow Black, 4GB RAM, 64GB Sto...  ₹12,499
# 865  Tecno Spark 7 Pro (Magnet Black 6GB RAM 64GB S...  ₹10,999
# 866  Oppo A54 (Moonlight Gold, 4GB RAM, 128GB Stora...  ₹14,490
#
#                  Rating ReviewCount  \
# 0    4.2 out of 5 stars       1,605
# 1    4.2 out of 5 stars       1,067
# 2    4.2 out of 5 stars      49,812
# 3    4.2 out of 5 stars      53,686
# ...

# %% [markdown]
# ### 8.Write a python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day extended forecast display for the city. The data should include period, short description, temperature and description.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
page = requests.get("https://forecast.weather.gov/MapClick.php?textField1=37.78&textField2=-122.42#.YMy5YC7ivcc")

# %%
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, "lxml")

# %%
seven_day = soup.find_all(id="seven-day-forecast")[0]
forecast_items = seven_day.find_all(class_="tombstone-container")

# %%
tonight = forecast_items[0]

# %%
print(tonight.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Today
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Today: Sunny, with a high near 76. Breezy, with a light and variable wind becoming west southwest 17 to 22 mph in the afternoon. Winds could gust as high as 28 mph. " class="forecast-icon" src="DualImage.php?i=few&amp;j=wind_few" title="Today: Sunny, with a high near 76. Breezy, with a light and variable wind becoming west southwest 17 to 22 mph in the afternoon. Winds could gust as high as 28 mph. "/>
#  </p>
#  <p class="short-desc">
#   Sunny then
#   <br/>
#   Sunny and
#   <br/>
#   Breezy
#  </p>
#  <p class="temp temp-high">
#   High: 76 °F
#  </p>
# </div>

# %%
period = tonight.find(class_= "period-name").get_text()

# %%
short_desc = tonight.find(class_ = "short-desc")

# %%
short_desc.get_text()
# Out:
# 'Sunny thenSunny andBreezy'

# %%
image = tonight.select("img")[0]

# %%
image["title"]
# Out:
# 'Today: Sunny, with a high near 76. Breezy, with a light and variable wind becoming west southwest 17 to 22 mph in the afternoon. Winds could gust as high as 28 mph. '

# %%
img = tonight.find("img")

# %%
desc = img["title"]

# %%
print(desc)
# Out:
# Today: Sunny, with a high near 76. Breezy, with a light and variable wind becoming west southwest 17 to 22 mph in the afternoon. Winds could gust as high as 28 mph.

# %%
seven_day.prettify
# Out:
# <bound method Tag.prettify of <div class="panel panel-default" id="seven-day-forecast">
# <div class="panel-heading">
# <b>Extended Forecast for</b>
# <h2 class="panel-title">
# 	    	    San Francisco CA	</h2>
# </div>
# <div class="panel-body" id="seven-day-forecast-body">
# <div id="seven-day-forecast-container"><ul class="list-unstyled" id="seven-day-forecast-list"><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Today<br/><br/></p>
# ...

# %%
period_tags = seven_day.select(".tombstone-container .period-name")

# %%
print(period_tags)
# Out:
# [<p class="period-name">Today<br/><br/></p>, <p class="period-name">Tonight<br/><br/></p>, <p class="period-name">Saturday<br/><br/></p>, <p class="period-name">Saturday<br/>Night</p>, <p class="period-name">Sunday<br/><br/></p>, <p class="period-name">Sunday<br/>Night</p>, <p class="period-name">Monday<br/><br/></p>, <p class="period-name">Monday<br/>Night</p>, <p class="period-name">Tuesday<br/><br/></p>]

# %%
periods =[pa.get_text() for pa in period_tags]

# %%
periods
# Out:
# ['Today',
#  'Tonight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight',
#  'Monday',
#  'MondayNight',
#  'Tuesday']

# %%
short_desc_tags = seven_day.select(".tombstone-container .short-desc")

# %%
print(short_desc_tags)
# Out:
# [<p class="short-desc">Sunny then<br/>Sunny and<br/>Breezy</p>, <p class="short-desc">Mostly Clear</p>, <p class="short-desc">Sunny then<br/>Sunny and<br/>Breezy</p>, <p class="short-desc">Mostly Clear<br/>and Breezy<br/>then Partly<br/>Cloudy</p>, <p class="short-desc">Sunny then<br/>Sunny and<br/>Breezy</p>, <p class="short-desc">Partly Cloudy</p>, <p class="short-desc">Mostly Sunny</p>, <p class="short-desc">Mostly Cloudy</p>, <p class="short-desc">Mostly Sunny</p>]

# %%
short_description = [pa.get_text() for pa in short_desc_tags]

# %%
short_description
# Out:
# ['Sunny thenSunny andBreezy',
#  'Mostly Clear',
#  'Sunny thenSunny andBreezy',
#  'Mostly Clearand Breezythen PartlyCloudy',
#  'Sunny thenSunny andBreezy',
#  'Partly Cloudy',
#  'Mostly Sunny',
#  'Mostly Cloudy',
#  'Mostly Sunny']

# %%
temp_tags = seven_day.select(".tombstone-container .temp")

# %%
print(temp_tags)
# Out:
# [<p class="temp temp-high">High: 76 °F</p>, <p class="temp temp-low">Low: 56 °F</p>, <p class="temp temp-high">High: 73 °F</p>, <p class="temp temp-low">Low: 56 °F</p>, <p class="temp temp-high">High: 71 °F</p>, <p class="temp temp-low">Low: 57 °F</p>, <p class="temp temp-high">High: 69 °F</p>, <p class="temp temp-low">Low: 58 °F</p>, <p class="temp temp-high">High: 68 °F</p>]

# %%
temp_description = [pa.get_text() for pa in temp_tags]

# %%
print(temp_description)
# Out:
# ['High: 76 °F', 'Low: 56 °F', 'High: 73 °F', 'Low: 56 °F', 'High: 71 °F', 'Low: 57 °F', 'High: 69 °F', 'Low: 58 °F', 'High: 68 °F']

# %%
temp_description
# Out:
# ['High: 76 °F',
#  'Low: 56 °F',
#  'High: 73 °F',
#  'Low: 56 °F',
#  'High: 71 °F',
#  'Low: 57 °F',
#  'High: 69 °F',
#  'Low: 58 °F',
#  'High: 68 °F']

# %%
image_tags = seven_day.select(".tombstone-container img")

# %%
image_tags
# Out:
# [<img alt="Today: Sunny, with a high near 76. Breezy, with a light and variable wind becoming west southwest 17 to 22 mph in the afternoon. Winds could gust as high as 28 mph. " class="forecast-icon" src="DualImage.php?i=few&amp;j=wind_few" title="Today: Sunny, with a high near 76. Breezy, with a light and variable wind becoming west southwest 17 to 22 mph in the afternoon. Winds could gust as high as 28 mph. "/>,
#  <img alt="Tonight: Mostly clear, with a low around 56. Southwest wind 9 to 18 mph, with gusts as high as 24 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Tonight: Mostly clear, with a low around 56. Southwest wind 9 to 18 mph, with gusts as high as 24 mph. "/>,
# ...

# %%
image_description = [d["title"] for d in image_tags]

# %%
image_description
# Out:
# ['Today: Sunny, with a high near 76. Breezy, with a light and variable wind becoming west southwest 17 to 22 mph in the afternoon. Winds could gust as high as 28 mph. ',
#  'Tonight: Mostly clear, with a low around 56. Southwest wind 9 to 18 mph, with gusts as high as 24 mph. ',
#  'Saturday: Sunny, with a high near 73. Breezy, with a west southwest wind 11 to 16 mph increasing to 18 to 23 mph in the afternoon. Winds could gust as high as 30 mph. ',
#  'Saturday Night: Mostly clear, with a low around 56. Breezy, with a west southwest wind 16 to 23 mph, with gusts as high as 30 mph. ',
#  'Sunday: Sunny, with a high near 71. Breezy, with a west southwest wind 15 to 22 mph, with gusts as high as 28 mph. ',
#  'Sunday Night: Partly cloudy, with a low around 57.',
#  'Monday: Mostly sunny, with a high near 69.',
#  'Monday Night: Mostly cloudy, with a low around 58.',
#  'Tuesday: Mostly sunny, with a high near 68.']

# %%
weather = pd.DataFrame( 
   { "Periods" : periods,
    "Short_description" : short_description,
    "Temp_description" : temp_description,
    "Image_description" : image_description
}
)

# %%
weather
# Out:
#          Periods                        Short_description Temp_description  \
# 0          Today                Sunny thenSunny andBreezy      High: 76 °F
# 1        Tonight                             Mostly Clear       Low: 56 °F
# 2       Saturday                Sunny thenSunny andBreezy      High: 73 °F
# 3  SaturdayNight  Mostly Clearand Breezythen PartlyCloudy       Low: 56 °F
# 4         Sunday                Sunny thenSunny andBreezy      High: 71 °F
# 5    SundayNight                            Partly Cloudy       Low: 57 °F
# 6         Monday                             Mostly Sunny      High: 69 °F
# 7    MondayNight                            Mostly Cloudy       Low: 58 °F
# 8        Tuesday                             Mostly Sunny      High: 68 °F
#
#                                    Image_description
# 0  Today: Sunny, with a high near 76. Breezy, wit...
# 1  Tonight: Mostly clear, with a low around 56. S...
# 2  Saturday: Sunny, with a high near 73. Breezy, ...
# ...

# %% [markdown]
# ### 9. Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title, company name, CTC, and apply date.

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://internshala.com/fresher-jobs")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml">\n    <head>\n        <meta http-equiv="X-UA-Compatible" content="IE=9" />\n        <meta charset="UTF-8" />\n        <meta name="viewport" content="width=device-width, initial-scale=1.0 user-scalable=0" />\n        <meta property="fb:app_id" content="272234782795210" />\n        <meta property="og:type" content="article" />\n                    <meta property="og:image:width" content="1200" />\n            <meta property="og:image:height" content="630" />\n                    <meta name="twitter:site" content="@Internshala" />\n                    <meta name="twitter:card" content="summary_large_image" />\n        \n        <meta name="twitter:creator" content="@internshala" />\n                <meta name="theme-color" content="#ffffff" />\n        <meta name="msapplication-navbutton-color" content="#ffffff"/>\n        <meta name="format-detection"
# ...

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
# <meta content="272234782795210" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="@Internshala" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@internshala" name="twitter:creator"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="#ffffff" name="msapplication-navbutton-color"/>
# <meta content="telephone=no" name="format-detection"/>
# <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
# ...

# %%
title= []

detail = soup.find_all('div', class_="heading_4_5 profile")

for i in detail:

    title.append(i.text.replace('\n',''))

# %%
C_title=[]
for i in range(0,len(title),1):

    C_title.append(title[i].strip())

# %%
C_title
# Out:
# ['Product Developer - Mathematics',
#  'Sales Development Representative',
#  'Full Stack Engineer',
#  'Junior ReactJS Developer',
#  'Marketing Manager',
#  'Product Marketing Associate',
#  'Administration Associate',
#  'Recruiter',
#  'Associate Software Developer',
#  'Project Coordinator',
#  'Web Developer',
#  'Software Engineer Trainee',
#  'Business Development Specialist (Sales & Marketing)',
#  'Business Development Executive',
#  'Associate Front End Developer',
#  'Corporate Sales Executive',
#  'Associate Software Developer (Full-Stack - React And Node)',
#  'Customer Relationship Specialist',
#  'Associate Editor Engagement',
#  'Management Consultant Associate',
#  'Web Analytics Developer',
#  'Junior Social Media Marketing Manager',
#  'Junior Social Media Marketing Associate',
#  'Business Development Manager (Digital Marketing Sales)',
#  'Business Development Executive',
#  'Accountant',
#  'Research Associate',
#  'Assistant Coordinator - Tender Department',
# ...

# %%
C_names= []

detail = soup.find_all('a', class_="link_display_like_text")

for i in detail:

    C_names.append(i.text.replace('\n','').strip())

# %%
company_names=[]
for i in range(0,len(C_names),1):

    company_names.append(C_names[i])

# %%
company_names
# Out:
# ['Open Door Education',
#  'Content Beta',
#  'Softway Solutions Private Limited',
#  'DeepThought Edutech Ventures Private Limited',
#  'Saltoro Coffee Roasters',
#  'WebMOBI',
#  'Global Sun',
#  'Radish Consultants Private Limited',
#  'Medico Healthcare Services & Technologies',
#  'Edupixels',
#  'Manufac Analytics Private Limited',
#  'Swabhav Techlabs',
#  'Claraeon Learning Private Limited',
#  'Picostone',
#  'AIMonk Labs Technology Limited',
#  '369 Zoss Waters',
#  'SleekSky LLC',
#  'InPhase Power Technologies',
#  'Cactus Communications Private Limited',
#  'StrategyCo.Global',
#  'DataVinci Private Limited',
#  'The Test Tribe',
#  'Glu Studios',
#  'Graygraph Technologies LLC',
#  'BookLeaf Publishing',
#  'Ravi Ladia & Co',
#  'Market Vistas Consumer Insights',
#  'Global Source Trading LLC',
#  'Blue Rose Publishers',
#  'Best Roadways Limited',
#  'Geekster',
#  'InfyBytes AI Labs Private Limited',
#  'Moxie.xyz',
#  'GREedge',
#  'Fullmoon Outdoor Web Solutions',
# ...

# %%
loc= []

detail = soup.find_all('p', attrs={'id':"location_names"})

for i in detail:

    loc.append(i.text.replace('\n','').strip())

# %%
locations=[]
for i in range(0,len(loc),1):

    locations.append(loc[i])

# %%
locations
# Out:
# ['Bangalore',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Delhi, Noida',
#  'Remote',
#  'Remote',
#  'Secunderabad, Hyderabad',
#  'Hyderabad',
#  'Remote',
#  'Gurgaon, Pune',
#  'Mumbai',
#  'Hyderabad',
#  'Mumbai',
#  'Bangalore',
#  'Remote',
#  'Ahmedabad',
#  'Bangalore',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Navi Mumbai, Mumbai',
#  'Delhi',
#  'Ghaziabad, Noida',
#  'Remote',
#  'Hyderabad',
#  'Mumbai',
#  'Remote',
#  'Delhi, Noida',
#  'Mumbai',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Agra, Chandigarh, Dehradun, Delhi, Ghaziabad, Gurgaon, Lucknow, Meerut, Mohali, Bhopal, Noida, Nainital, Rajasthan',
#  'Remote']

# %%
ctc= []

detail = soup.find_all('div', class_="item_body")

for i in detail:

    ctc.append(i.text.replace('\n',''))

# %%
Ctc=[]
for i in range(1,len(ctc),3):

    Ctc.append(ctc[i].strip())

# %%
Ctc
# Out:
# ['7 - 8 LPA',
#  '3 - 4 LPA',
#  '5.5 - 9 LPA',
#  '3 - 5 LPA',
#  '3.2 - 3.5 LPA',
#  '3 LPA',
#  '3 - 3.2 LPA',
#  '3 - 5 LPA',
#  '3 - 3.2 LPA',
#  '3 LPA',
#  '3 - 4 LPA',
#  '3 - 3.5 LPA',
#  '3 LPA',
#  '3 - 6.5 LPA',
#  '6 - 7 LPA',
#  '3 - 5 LPA',
#  '4 LPA',
#  '3 - 3.5 LPA',
#  '3 - 4 LPA',
#  '4.5 - 7 LPA',
#  '4.99 - 5 LPA',
#  '3 - 4 LPA',
#  '3 - 3.6 LPA',
#  '3 - 4.5 LPA',
#  '3 - 3.6 LPA',
#  '3 LPA',
#  '3 - 3.25 LPA',
#  '3 LPA',
#  '3 - 3.5 LPA',
#  '3 LPA',
#  '3 - 3.5 LPA',
#  '3 - 4 LPA',
#  '9 LPA',
#  '3.75 LPA',
#  '4 - 4.2 LPA',
#  '3 LPA',
#  '3.5 - 5 LPA',
#  '3.6 - 10 LPA',
#  '3 - 4 LPA',
#  '3.3 - 4 LPA']

# %%
date= []

detail = soup.find_all('div', class_="item_body")

for i in detail:

    date.append(i.text.replace('\n',''))

# %%
Apply_date=[]
for i in range(2,len(date),3):

    Apply_date.append(date[i])

# %%
Apply_date
# Out:
# ["22 Jul' 21",
#  "22 Jul' 21",
#  "22 Jul' 21",
#  "22 Jul' 21",
#  "22 Jul' 21",
#  "22 Jul' 21",
#  "21 Jul' 21",
#  "21 Jul' 21",
#  "21 Jul' 21",
#  "21 Jul' 21",
#  "19 Jul' 21",
#  "19 Jul' 21",
#  "19 Jul' 21",
#  "19 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "18 Jul' 21",
#  "17 Jul' 21",
#  "17 Jul' 21",
#  "17 Jul' 21",
#  "17 Jul' 21",
#  "17 Jul' 21",
#  "16 Jul' 21",
#  "17 Jul' 21",
#  "16 Jul' 21",
#  "16 Jul' 21",
#  "17 Jul' 21",
#  "16 Jul' 21",
#  "16 Jul' 21",
#  "15 Jul' 21",
#  "15 Jul' 21",
#  "15 Jul' 21",
#  "14 Jul' 21",
#  "14 Jul' 21",
#  "11 Jul' 21",
#  "11 Jul' 21",
#  "11 Jul' 21"]

# %%
print(len(C_title),len(company_names),len(locations),len(Ctc),len(Apply_date))
# Out:
# 40 40 40 40 40

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['Title']=C_title
jobs['Company_Names']=company_names
jobs['Location']=locations
jobs['Ctc']=Ctc
jobs['Apply_date']=Apply_date

# %%
jobs.index+=1

# %%
jobs
# Out:
#                                                 Title  \
# 2                     Product Developer - Mathematics
# 3                    Sales Development Representative
# 4                                 Full Stack Engineer
# 5                            Junior ReactJS Developer
# 6                                   Marketing Manager
# 7                         Product Marketing Associate
# 8                            Administration Associate
# 9                                           Recruiter
# 10                       Associate Software Developer
# 11                                Project Coordinator
# 12                                      Web Developer
# 13                          Software Engineer Trainee
# 14  Business Development Specialist (Sales & Marke...
# 15                     Business Development Executive
# 16                      Associate Front End Developer
# 17                          Corporate Sales Executive
# ...

# %% [markdown]
# ### 10. Write a python program to scrape house details from mentioned url. It should include house title, location, area, emi and price3

# %%
from bs4 import BeautifulSoup
import requests

# %%
html_string = requests.get("https://www.nobroker.in/property/sale/bangalore/Bangalore/?searchParam=W3sibGF0IjoxMi45Njk5MzM0NDAzNjgxLCJsb24iOjc3LjU5ODE3NzAzMjg1MjIsInBsYWNlSWQiOiJDaElKYlU2MHlYQVdyanNSNEU5LVVlakQzX2ciLCJwbGFjZU5hbWUiOiJCYW5nYWxvcmUiLCJzaG93TWFwIjpmYWxzZX1d&type=BHK4").content
soup = BeautifulSoup(html_string, 'html.parser')

# %%
spans=soup.find_all('h2',attrs={"class":"heading-6 font-semi-bold nb__1AShY"})
spans
# Out:
# [<h2 class="heading-6 font-semi-bold nb__1AShY"><span itemprop="name">4 BHK Flat  For Sale  In Badarayan Nexus In Vidyaranyapura</span> <svg aria-hidden="true" class="jss1" focusable="false" role="presentation" viewbox="0 0 24 24"><path d="M0 0h24v24H0z" fill="none"></path><path d="M19 19H5V5h7V3H5c-1.11 0-2 .9-2 2v14c0 1.1.89 2 2 2h14c1.1 0 2-.9 2-2v-7h-2v7zM14 3v2h3.59l-9.83 9.83 1.41 1.41L19 6.41V10h2V3h-7z"></path></svg></h2>,
#  <h2 class="heading-6 font-semi-bold nb__1AShY"><span itemprop="name">4 BHK In Independent House  For Sale  In T. Dasarahalli</span> <svg aria-hidden="true" class="jss1" focusable="false" role="presentation" viewbox="0 0 24 24"><path d="M0 0h24v24H0z" fill="none"></path><path d="M19 19H5V5h7V3H5c-1.11 0-2 .9-2 2v14c0 1.1.89 2 2 2h14c1.1 0 2-.9 2-2v-7h-2v7zM14 3v2h3.59l-9.83 9.83 1.41 1.41L19 6.41V10h2V3h-7z"></path></svg></h2>,
# ...

# %%
record=[]
for result in spans:  
    name = result.find('span', attrs={'itemprop':'name'})
    record.append(name.text.replace('\n',''))
record
# Out:
# ['4 BHK Flat  For Sale  In Badarayan Nexus In Vidyaranyapura',
#  '4 BHK In Independent House  For Sale  In T. Dasarahalli',
#  '4 BHK In Independent House  For Sale  In Ngef Layout',
#  '4 BHK In Independent House  For Sale  In Marathahalli',
#  '4 BHK In Independent House  For Sale  In Ramamurthy Nagar',
#  '4 BHK In Independent House  For Sale  In J. P. Nagar',
#  '4 BHK In Independent House  For Sale  In Jagajyothi Layout',
#  '4 BHK Apartment  For Sale  In Aakruthi Sunshine Apartment In Kadubeesanahalli',
#  '4 BHK In Independent House  For Sale  In Kanakanagara Circle, Maragondanahalli',
#  '4 BHK In Independent House  For Sale  In Lingarajapuram']

# %%
len(record)
# Out:
# 10

# %%
len(area)
# Out:
# 10

# %%
len(location)
# Out:
# 20

# %%
full_info = []

detail = soup.find_all('div',class_="font-semi-bold heading-6")

for i in detail:

    full_info.append(i.text)

# %%
EMI=[]
for i in range(1,len(full_info),3):

    EMI.append(full_info[i])

# %%
EMI
# Out:
# ['₹65,911/Month',
#  '₹1.72 Lacs/Month',
#  '₹2.15 Lacs/Month',
#  '₹41,266/Month',
#  '₹27,510/Month',
#  '₹85,971/Month',
#  '₹1.49 Lacs/Month',
#  '₹79,667/Month',
#  '₹63,045/Month',
#  '₹80,240/Month']

# %%
len(EMI)
# Out:
# 10

# %%
Price_info = []

detail = soup.find_all('div',class_="location")

for i in detail:

    Price_info.append(i.text)

# %%
Price=[]
for i in range(2,len(Price_info),3):

    Price.append(Price_info[i])

# %%
Price
# Out:
# ['₹1.15 Crores',
#  '₹3 Crores',
#  '₹3.75 Crores',
#  '₹72 Lacs',
#  '₹48 Lacs',
#  '₹1.5 Crores',
#  '₹2.6 Crores',
#  '₹1.39 Crores',
#  '₹1.1 Crores',
#  '₹1.4 Crores']

# %%
loc= []

detail = soup.find_all('span',attrs={"itemprop":"streetAddress"})

for i in detail:

    loc.append(i.text)

# %%
loc
# Out:
# ['Vidyaranyapura',
#  'Vidyaranyapura',
#  'T. Dasarahalli',
#  'T. Dasarahalli',
#  'NGEF Layout',
#  'NGEF Layout',
#  'Marathahalli',
#  'Marathahalli',
#  'Ramamurthy Nagar',
#  'Ramamurthy Nagar',
#  'J. P. Nagar',
#  'J. P. Nagar',
#  'Jagajyothi Layout',
#  'Jagajyothi Layout',
#  'Kadubeesanahalli',
#  'Kadubeesanahalli',
#  'Kanakanagara Circle, Maragondanahalli',
#  'Kanakanagara Circle, Maragondanahalli',
#  'Lingarajapuram',
#  'Lingarajapuram']

# %%
Location=[]
for i in range(1,len(loc),2):

    Location.append(loc[i])

# %%
Location
# Out:
# ['Vidyaranyapura',
#  'T. Dasarahalli',
#  'NGEF Layout',
#  'Marathahalli',
#  'Ramamurthy Nagar',
#  'J. P. Nagar',
#  'Jagajyothi Layout',
#  'Kadubeesanahalli',
#  'Kanakanagara Circle, Maragondanahalli',
#  'Lingarajapuram']

# %%
area= []

detail = soup.find_all('span',attrs={"itemprop":"location"})

for i in detail:

    area.append(i.text)

# %%
area
# Out:
# ['Srinidhi Layout,,8th d main c block,nera Sunrays Yoga & Wellness Center-Bangalore4 BHK Flat  For Sale  In Badarayan Nexus In VidyaranyapuraVidyaranyapurabangalore',
#  'Independent House, # 497 ,6th main road Bhuvaneshwari Nagar4 BHK In Independent House  For Sale  In T. DasarahalliT. Dasarahallibangalore',
#  'Independent House, 450, NGEF Main Road , Behind RNZ/Metro4 BHK In Independent House  For Sale  In Ngef LayoutNGEF Layoutbangalore560038',
#  'Independent House, Krishna Reddy Garden 2nd Cross Chowdeshwari Temple Street Marathahalli Bangalore 5600374 BHK In Independent House  For Sale  In MarathahalliMarathahallibangalore',
#  'Independent House, Shanthi Layout Main Rd near Krishna Provision store4 BHK In Independent House  For Sale  In Ramamurthy NagarRamamurthy Nagarbangalore',
#  'Independent House, 5th Phase, Vinayaka Nagar, Near Fakhri Markaz4 BHK In Independent House  For Sale  In J. P. NagarJ. P. Nagarbangalore',
# ...

# %%
Area=[]
for i in range(0,len(area),1):

    Area.append(area[i])

# %%
Area
# Out:
# ['Srinidhi Layout,,8th d main c block,nera Sunrays Yoga & Wellness Center-Bangalore4 BHK Flat  For Sale  In Badarayan Nexus In VidyaranyapuraVidyaranyapurabangalore',
#  'Independent House, # 497 ,6th main road Bhuvaneshwari Nagar4 BHK In Independent House  For Sale  In T. DasarahalliT. Dasarahallibangalore',
#  'Independent House, 450, NGEF Main Road , Behind RNZ/Metro4 BHK In Independent House  For Sale  In Ngef LayoutNGEF Layoutbangalore560038',
#  'Independent House, Krishna Reddy Garden 2nd Cross Chowdeshwari Temple Street Marathahalli Bangalore 5600374 BHK In Independent House  For Sale  In MarathahalliMarathahallibangalore',
#  'Independent House, Shanthi Layout Main Rd near Krishna Provision store4 BHK In Independent House  For Sale  In Ramamurthy NagarRamamurthy Nagarbangalore',
#  'Independent House, 5th Phase, Vinayaka Nagar, Near Fakhri Markaz4 BHK In Independent House  For Sale  In J. P. NagarJ. P. Nagarbangalore',
# ...

# %%
len(Area)
# Out:
# 10

# %%
print(len(record),len(Area),len(EMI),len(Price),len(Location))
# Out:
# 10 10 10 10 10

# %%
name=[]
for i in range(0,len(full_info),1):

    name.append(full_info[i])

# %%
name
# Out:
# ['4 BHK Flat  For Sale  In Badarayan Nexus In Vidyaranyapura ',
#  '4 BHK In Independent House  For Sale  In T. Dasarahalli ',
#  '4 BHK In Independent House  For Sale  In Ngef Layout ',
#  '4 BHK In Independent House  For Sale  In Marathahalli ',
#  '4 BHK In Independent House  For Sale  In Ramamurthy Nagar ',
#  '4 BHK In Independent House  For Sale  In J. P. Nagar ',
#  '4 BHK In Independent House  For Sale  In Jagajyothi Layout ',
#  '4 BHK Apartment  For Sale  In Aakruthi Sunshine Apartment In Kadubeesanahalli ',
#  '4 BHK In Independent House  For Sale  In Kanakanagara Circle, Maragondanahalli ',
#  '4 BHK In Independent House  For Sale  In Lingarajapuram ']

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=record
jobs['Area']=Area
jobs['EMI']=EMI
jobs['Price']=Price
jobs['Location']=Location

# %%
jobs.index+=1

# %%
jobs.index
# Out:
# RangeIndex(start=1, stop=11, step=1)

# %%
jobs
# Out:
#                                                 title  \
# 1   4 BHK Flat  For Sale  In Badarayan Nexus In Vi...
# 2   4 BHK In Independent House  For Sale  In T. Da...
# 3   4 BHK In Independent House  For Sale  In Ngef ...
# 4   4 BHK In Independent House  For Sale  In Marat...
# 5   4 BHK In Independent House  For Sale  In Ramam...
# 6   4 BHK In Independent House  For Sale  In J. P....
# 7   4 BHK In Independent House  For Sale  In Jagaj...
# 8   4 BHK Apartment  For Sale  In Aakruthi Sunshin...
# 9   4 BHK In Independent House  For Sale  In Kanak...
# 10  4 BHK In Independent House  For Sale  In Linga...
#
#                                                  Area               EMI  \
# 1   Srinidhi Layout,,8th d main c block,nera Sunra...     ₹65,911/Month
# 2   Independent House, # 497 ,6th main road Bhuvan...  ₹1.72 Lacs/Month
# 3   Independent House, 450, NGEF Main Road , Behin...  ₹2.15 Lacs/Month
# 4   Independent House, Krishna Reddy Garden 2nd Cr...     ₹41,266/Month
# ...
